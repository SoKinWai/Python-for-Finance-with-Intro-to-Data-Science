# %% [markdown]
# Student name: Jianwei Su
#
# Date: 06/10/2022
#
# 9.2

# %% [markdown]
# # Create a DataFrame of 1,000,000 normally distributed random values. Plot a histogram using Pandas hist method. Test with several different values for bins – how do different numbers of bins affect the shape of the chart?

# %%
import numpy as np
import pandas as pd

# Create a DataFrame of 1,000,000 normally distributed random values.
s = np.random.normal(0, 0.1, 1000000)
len(s)
# Out:
# 1000000

# %%
df = pd.DataFrame({'Normally distributed random values':s})
df.head()
# Out:
#    Normally distributed random values
# 0                           -0.230422
# 1                            0.059446
# 2                            0.011417
# 3                           -0.128469
# 4                           -0.012120

# %%
#Plot a histogram using Pandas hist method.
df['Normally distributed random values'].hist(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Test with several different values for bins

# %%
df['Normally distributed random values'].hist(figsize=(10,5), bins=50)
# Out:
# <AxesSubplot:>

# %%
df['Normally distributed random values'].hist(figsize=(10,5), bins=100)
# Out:
# <AxesSubplot:>

# %%
df['Normally distributed random values'].hist(figsize=(10,5), bins=200)
# Out:
# <AxesSubplot:>

# %%
df['Normally distributed random values'].hist(figsize=(10,5), bins=300)
# Out:
# <AxesSubplot:>

# %%
df['Normally distributed random values'].hist(figsize=(10,5), bins=500)
# Out:
# <AxesSubplot:>

# %%
df['Normally distributed random values'].hist(figsize=(10,5), bins=1000)
# Out:
# <AxesSubplot:>

# %% [markdown]
# how do different numbers of bins affect the shape of the chart?
#
# When I added more bins, the shape of the chart became smoother. However, there is a marginal amount of adding bins to make the chart become smoother. By testing results, that amount is 300.
